# %%
import pandas as pd
df_expert = pd.read_csv("../outputs/trajectories_expert_5k.csv")      # adjust filename
df_expert.tail(10)
# Out:
#       query_id                                 query  step  \
# 8772   1089011                        verbose define     2
# 8773    440838  list of foods to reduce inflammation     0
# 8774    612212            what county is sabula iowa     0
# 8775    153763    distance from zimbabwe to tanzania     0
# 8776    153763    distance from zimbabwe to tanzania     1
# 8777    153763    distance from zimbabwe to tanzania     2
# 8778    722250                  what is bank charter     0
# 8779    995447           definition of anemia by age     0
# 8780   1096816       how many people go to a concert     0
# 8781   1096816       how many people go to a concert     1
#
#                                                   state  action    reward  \
# 8772  [2.0, 0.04368500038981438, 0.01255833450704813...       1 -0.067929
# 8773  [6.0, 0.026069529354572296, 0.0245872847735881...       3  0.000000
# 8774  [5.0, 0.017071129754185677, 0.0541469976305961...       3  0.000000
# ...

# %%
import pandas as pd
df_rerank = pd.read_csv("../outputs/trajectories_rerank_test_queries_5.csv")      # adjust filename
df_rerank

# %%
import pandas as pd
df_random = pd.read_csv("../outputs/trajectories_random_5k.csv")      # adjust filename
df_random.tail(10)
# Out:
#        query_id                               query  step  \
# 10353    612212          what county is sabula iowa     2
# 10354    153763  distance from zimbabwe to tanzania     0
# 10355    153763  distance from zimbabwe to tanzania     1
# 10356    153763  distance from zimbabwe to tanzania     2
# 10357    722250                what is bank charter     0
# 10358    995447         definition of anemia by age     0
# 10359    995447         definition of anemia by age     1
# 10360    995447         definition of anemia by age     2
# 10361   1096816     how many people go to a concert     0
# 10362   1096816     how many people go to a concert     1
#
#                                                    state  action    reward  \
# 10353  [5.0, 0.017071129754185677, 0.0541469976305961...       3  0.000000
# 10354  [5.0, -0.038696687668561935, 0.062422979623079...       0 -0.223604
# 10355  [5.0, -0.038696687668561935, 0.062422979623079...       2 -0.136465
# ...

# %%
from pathlib import Path

from d3rlpy.dataset import InfiniteBuffer, ReplayBuffer


EXPERT_DATASET_PATH = Path("../outputs/mdp_dataset_trajectories_expert_5k.h5")
RANDOM_DATASET_PATH = Path("../outputs/mdp_dataset_trajectories_random_5k.h5")
TWO_POLICIES_DATASET_PATH = Path("../outputs/mdp_dataset_trajectories_two_policies_5k.h5")

mdp_dataset_expert = ReplayBuffer.load(EXPERT_DATASET_PATH.open("rb"), InfiniteBuffer())
mdp_dataset_random = ReplayBuffer.load(RANDOM_DATASET_PATH.open("rb"), InfiniteBuffer())
for episode in mdp_dataset_random.episodes:
       mdp_dataset_expert.append_episode(episode)
       print(f"Merged episodes: {mdp_dataset_expert.size()}")

    # Do not overwrite either source dataset.
with TWO_POLICIES_DATASET_PATH.open("w+b") as f:
    mdp_dataset_expert.dump(f)
# Out:
# 2026-07-21 17:47.51 [info     ] Signatures have been automatically determined. action_signature=Signature(dtype=[dtype('int64')], shape=[(1,)]) observation_signature=Signature(dtype=[dtype('float32')], shape=[(399,)]) reward_signature=Signature(dtype=[dtype('float32')], shape=[(1,)])
# 2026-07-21 17:47.51 [info     ] Action-space has been automatically determined. action_space=<ActionSpace.DISCRETE: 2>
# 2026-07-21 17:47.51 [info     ] Action size has been automatically determined. action_size=4
# 2026-07-21 17:47.55 [info     ] Signatures have been automatically determined. action_signature=Signature(dtype=[dtype('int64')], shape=[(1,)]) observation_signature=Signature(dtype=[dtype('float32')], shape=[(399,)]) reward_signature=Signature(dtype=[dtype('float32')], shape=[(1,)])
# 2026-07-21 17:47.55 [info     ] Action-space has been automatically determined. action_space=<ActionSpace.DISCRETE: 2>
# ...

# %%
import pandas as pd
df_test_results = pd.read_csv("../outputs/cql_test_results2.csv")      
df_test_results
# Out:
#     query_id                                         query_text  step  action  \
# 0    1048579                                       what is pcnt     0       3
# 1     262156                  how long is a college hockey game     0       1
# 2     262156                  how long is a college hockey game     1       3
# 3    1048601                          what is pastoral medicine     0       0
# 4    1048601  What is pastoral medicine, including its defin...     1       3
# ..       ...                                                ...   ...     ...
# 81   1051364                          who sings love shack baby     0       3
# 82   1051376  what is meant by solution concentration and wh...     0       3
# 83   1051401                   what is meant by robust software     0       0
# 84   1051401  What is meant by robust software in the contex...     1       0
# 85   1051401  What is the definition and meaning of robust s...     2       3
#
# ...
